# %%
import pandas as pd # type: ignore

# %%
df = pd.read_csv("startup_funding.csv")
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
print(df.shape)
# Out:
# (3044, 10)

# %%
#clean thisss
sorted(df['Startup Name'].unique().tolist())
# Out:
# ['"BYJU\\\\\'S"',
#  '#Fame',
#  '121Policy',
#  '19th mile',
#  '1Crowd',
#  '1mg',
#  '1mg (Healthkartplus)',
#  '20Dresses',
#  '33Coupons',
#  '360Ride',
#  '3Dexter',
#  '3HCare',
#  '3rdFlix',
#  '48East',
#  '4tigo',
#  '5th Vital',
#  '6Degree',
#  '75F',
#  '91SpringBoard',
#  '99Games',
#  '99PerHour',
#  '9Stacks',
#  'A&R Bon Vivants',
#  'ABI Health',
#  'AEON Learning',
#  'AHA Taxis',
#  'AYE Finance',
#  'AadharAPI.com',
#  'Aadyah',
#  'Aahaa',
#  'Aahaa Stores',
#  'Aarav UAV',
#  'Aasaanjobs',
#  'Aashiyaan',
#  'Aavishkaar-Intellecap Group',
#  'AbeRuk',
#  'Abhibus',
#  'Absentia',
#  'Absentia VR',
#  'Ace Turtle',
#  'Ace2three',
#  'Acko',
#  'ActOnMagic',
#  'Actionable Analytics',
#  'Active AI',
#  'Active.ai',
#  'Actofit',
#  'Ad2pro',
#  'AdPushUp',
#  'AdStringO',
#  'AdUrCup',
#  'AdWyze',
#  'Address Health',
#  'AdmitKard',
#  'Advanced Structures India',
#  'Advantage Club',
#  'Advenio',
#  'Adytude',
#  'Aequm',
#  'AerMed',
#  'Affimity',
# ...

# %%
df['Investors Name'].fillna("UnKnown" , inplace=True)

# %%
sorted(df['Investors Name'].value_counts().index)
# Out:
# ['"Kedaraa Capital, Ontario Teachers\\\\\'"',
#  '021 Capita, Binny Bansal',
#  '1Crowd',
#  '1Crowd (through crowd funding)',
#  '1Crowd (through crowdfunding)',
#  '1Crowd, Ankur Capital',
#  '1Crowd, Eureka Forbes Ltd, Shapoorji Pallonji & Co. Ltd.',
#  '3 undisclosed HNIs',
#  '3 undisclosed investors',
#  '3One4 Capital',
#  '3one4 Capital, Mumbai Angels, Aarin Capital',
#  '3one4 Capital, Tracxn Labs, Aaruha Technology Fund, Endiya Partners',
#  '3one4 capital',
#  '500 Startups',
#  '500 Startups, IDG Ventures & Advantedge fund, Neeraj Arora, Leon Seynave',
#  '500 Startups, IvyCap Ventures',
#  '500 Startups, Littlerock, Singularity Ventures',
#  '500 Startups, Mato Peric & Others',
#  '500 Startups, Mato Peric, TracxnLabs',
#  '500 Startups, Purvi Capital, Rajan Anandan, Abhishek Gupta',
#  '500 Startups, Smile Multimedia, Kunal Bahl, Rohit Bansal, Girish Matrubootham',
#  '500 Startups, TV Mohandas Pai, Tandem Capital, Vikram Chachra, Aloke Bajpai',
#  '50K Ventures',
# ...

# %%
sorted(df['Startup Name'].unique())
# Out:
# ['"BYJU\\\\\'S"',
#  '#Fame',
#  '121Policy',
#  '19th mile',
#  '1Crowd',
#  '1mg',
#  '1mg (Healthkartplus)',
#  '20Dresses',
#  '33Coupons',
#  '360Ride',
#  '3Dexter',
#  '3HCare',
#  '3rdFlix',
#  '48East',
#  '4tigo',
#  '5th Vital',
#  '6Degree',
#  '75F',
#  '91SpringBoard',
#  '99Games',
#  '99PerHour',
#  '9Stacks',
#  'A&R Bon Vivants',
#  'ABI Health',
#  'AEON Learning',
#  'AHA Taxis',
#  'AYE Finance',
#  'AadharAPI.com',
#  'Aadyah',
#  'Aahaa',
#  'Aahaa Stores',
#  'Aarav UAV',
#  'Aasaanjobs',
#  'Aashiyaan',
#  'Aavishkaar-Intellecap Group',
#  'AbeRuk',
#  'Abhibus',
#  'Absentia',
#  'Absentia VR',
#  'Ace Turtle',
#  'Ace2three',
#  'Acko',
#  'ActOnMagic',
#  'Actionable Analytics',
#  'Active AI',
#  'Active.ai',
#  'Actofit',
#  'Ad2pro',
#  'AdPushUp',
#  'AdStringO',
#  'AdUrCup',
#  'AdWyze',
#  'Address Health',
#  'AdmitKard',
#  'Advanced Structures India',
#  'Advantage Club',
#  'Advenio',
#  'Adytude',
#  'Aequm',
#  'AerMed',
#  'Affimity',
# ...

# %%
df['Startup Name'] = df['Startup Name'].str.replace(r"\\" , "" ,regex=True).replace(r"#" , "" ,regex=True)

# %%
sorted(df['Startup Name'].value_counts().index)
# Out:
# ['"BYJU\'S"',
#  '121Policy',
#  '19th mile',
#  '1Crowd',
#  '1mg',
#  '1mg (Healthkartplus)',
#  '20Dresses',
#  '33Coupons',
#  '360Ride',
#  '3Dexter',
#  '3HCare',
#  '3rdFlix',
#  '48East',
#  '4tigo',
#  '5th Vital',
#  '6Degree',
#  '75F',
#  '91SpringBoard',
#  '99Games',
#  '99PerHour',
#  '9Stacks',
#  'A&R Bon Vivants',
#  'ABI Health',
#  'AEON Learning',
#  'AHA Taxis',
#  'AYE Finance',
#  'AadharAPI.com',
#  'Aadyah',
#  'Aahaa',
#  'Aahaa Stores',
#  'Aarav UAV',
#  'Aasaanjobs',
#  'Aashiyaan',
#  'Aavishkaar-Intellecap Group',
#  'AbeRuk',
#  'Abhibus',
#  'Absentia',
#  'Absentia VR',
#  'Ace Turtle',
#  'Ace2three',
#  'Acko',
#  'ActOnMagic',
#  'Actionable Analytics',
#  'Active AI',
#  'Active.ai',
#  'Actofit',
#  'Ad2pro',
#  'AdPushUp',
#  'AdStringO',
#  'AdUrCup',
#  'AdWyze',
#  'Address Health',
#  'AdmitKard',
#  'Advanced Structures India',
#  'Advantage Club',
#  'Advenio',
#  'Adytude',
#  'Aequm',
#  'AerMed',
#  'Affimity',
#  'Affordplan',
# ...

# %%
df['Startup Name'].duplicated().sum()
# Out:
# 585

# %%
df[df['Startup Name'].duplicated()]
# Out:
#       Sr No Date dd/mm/yyyy    Startup Name        Industry Vertical  \
# 21       22      18/11/2019      Healthians      Health and Wellness
# 44       45      01/08/2019        CarDekho               E-Commerce
# 65       66      01/07/2019        Uniphore  Artificial Intelligence
# 97       98      31/05/2019          Bira91        Food and Beverage
# 110     111      17/04/2019          Shuttl           Transportation
# ...     ...             ...             ...                      ...
# 3026   3027      21/01/2015    MyDreamStore                      NaN
# 3028   3029      21/05/2015         Villgro                      NaN
# 3034   3035      24/01/2015      Aasaanjobs                      NaN
# 3037   3038      27/01/2015    CarDekho.com                      NaN
# 3041   3042      30/01/2015  Mad Street Den                      NaN
#
#               SubVertical City  Location  \
# 21    Healthcare services        Gurgaon
# 44             Automotive        Gurgaon
# ...

# %%
df[df['Startup Name'] == 'Flipkart']
# Out:
#       Sr No Date dd/mm/yyyy Startup Name   Industry Vertical  \
# 651     652      11/08/2017     Flipkart           eCommerce
# 773     774      26/06/2017     Flipkart           eCommerce
# 966     967      21/03/2017     Flipkart           eCommerce
# 1032   1033      20/02/2017     Flipkart           eCommerce
# 2689   2690      04/06/2015     Flipkart  eCommerce platform
#
#                 SubVertical City  Location  \
# 651      Online Marketplace      Bangalore
# 773      Online marketplace      Bangalore
# 966   ECommerce Marketplace      Bangalore
# 1032     Online Marketplace      Bangalore
# 2689                    NaN      Bangalore
#
#                            Investors Name InvestmentnType   Amount in USD  \
# 651                              Softbank  Private Equity  2,50,00,00,000
# 773                               Naspers  Private Equity     7,10,00,000
# 966     Microsoft, eBay, Tencent Holdings  Private Equity  1,40,00,00,000
# ...

# %%
df[df['Startup Name'] == 'Flipkart.com']
# Out:
#       Sr No Date dd/mm/yyyy  Startup Name   Industry Vertical SubVertical  \
# 2648   2649      28/07/2015  Flipkart.com  Online Marketplace         NaN
#
#      City  Location                            Investors Name InvestmentnType  \
# 2648      Bangalore  Steadview Capital and existing investors  Private Equity
#
#      Amount in USD                           Remarks
# 2648  70,00,00,000  Late Stage, 10th Round More here

# %%
len(df['Investors Name'].unique()) ## there is various investor in one line
# Out:
# 2413

# %%
df['Investors Name'].str.split(",")
# Out:
# 0                 [Tiger Global Management]
# 1               [Susquehanna Growth Equity]
# 2                   [Sequoia Capital India]
# 3                          [Vinod Khatumal]
# 4                 [Sprout Venture Partners]
#                        ...
# 3039          [Asia Pacific Internet Group]
# 3040                       [KARSEMVEN Fund]
# 3041      [Exfinity Fund,  GrowX Ventures.]
# 3042                           [MakeMyTrip]
# 3043    [UK based Group of Angel Investors]
# Name: Investors Name, Length: 3044, dtype: object

# %%
df.drop(['Remarks'], axis=1 , inplace = True)

# %%
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
df.rename(columns={'Date dd/mm/yyyy' : 'Date' , 'Startup Name' : "Startup" , 'City  Location'  : 'City'} , inplace=True)

# %%
df.set_index(['Sr No'] , inplace=True)

# %%
df
# Out:
#              Date                       Startup    Industry Vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  SubVertical       City  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
df[df['Date'] == '05/072018']
# Out:
#             Date   Startup  Industry Vertical  \
# Sr No
# 193    05/072018  Loan Tap  Consumer Internet
#
#                                              SubVertical    City  \
# Sr No
# 193    Online Lending Platform For Salaried Professio...  Mumbai
#
#                                           Investors Name InvestmentnType  \
# Sr No
# 193    Shunwei Capital, Tuscan Ventures, Ashish Goenk...  Private Equity
#
#       Amount in USD
# Sr No
# 193       62,50,000

# %%
df[df['Date'] =='05/072018']
# Out:
#             Date   Startup  Industry Vertical  \
# Sr No
# 193    05/072018  Loan Tap  Consumer Internet
#
#                                              SubVertical    City  \
# Sr No
# 193    Online Lending Platform For Salaried Professio...  Mumbai
#
#                                           Investors Name InvestmentnType  \
# Sr No
# 193    Shunwei Capital, Tuscan Ventures, Ashish Goenk...  Private Equity
#
#       Amount in USD
# Sr No
# 193       62,50,000

# %%
df['Date'] = pd.to_datetime(df['Date'] , format='mixed' , errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               3040 non-null   datetime64[ns]
#  1   Startup            3044 non-null   object
#  2   Industry Vertical  2873 non-null   object
#  3   SubVertical        2108 non-null   object
#  4   City               2864 non-null   object
#  5   Investors Name     3044 non-null   object
#  6   InvestmentnType    3040 non-null   object
#  7   Amount in USD      2084 non-null   object
# dtypes: datetime64[ns](1), object(7)
# memory usage: 214.0+ KB

# %%
##  COnvert Amount of Cored rupeesss
df['Amount in USD'].fillna("0" , inplace=True)

# %%
df['Amount in USD'] = df['Amount in USD'].str.replace(',' , '')

# %%
df[df['Amount in USD'] == 'undisclosed']
# Out:
#             Date       Startup  Industry Vertical           SubVertical  \
# Sr No
# 21    2019-11-17  Burger Singh  Food and Beverage   Indian Burger Brand
# 90    2019-06-05  Ola Electric          Transport                  Cabs
# 92    2019-05-05    StyleDotMe         E-commerce  Fashion and Shopping
#
#             City                                     Investors Name  \
# Sr No
# 21       Gurgaon                                     RB Investments
# 90     Bengaluru                                          Tata Sons
# 92         Delhi  Indian Angel Network and other angel investors...
#
#       InvestmentnType Amount in USD
# Sr No
# 21            Venture   undisclosed
# 90           Series A   undisclosed
# 92       Bridge Round   undisclosed

# %%
df['Amount in USD'] = df['Amount in USD'].str.replace('undisclosed' , '0' )
df['Amount in USD'] = df['Amount in USD'].str.replace('unknown' , '0' )
df['Amount in USD'] = df['Amount in USD'].str.replace('Undisclosed' , '0' )

# %%
df = df[df['Amount in USD'].str.isdigit()]

# %%
df['Amount in USD'] = df['Amount in USD'].astype("float")
# Out:
# C:\Users\Deep Kothari\AppData\Local\Temp\ipykernel_16860\1947919850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Amount in USD'] = df['Amount in USD'].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               3026 non-null   datetime64[ns]
#  1   Startup            3029 non-null   object
#  2   Industry Vertical  2858 non-null   object
#  3   SubVertical        2104 non-null   object
#  4   City               2849 non-null   object
#  5   Investors Name     3029 non-null   object
#  6   InvestmentnType    3027 non-null   object
#  7   Amount in USD      3029 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 213.0+ KB

# %%
df
# Out:
#             Date                       Startup    Industry Vertical  \
# Sr No
# 1     2020-09-01                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-09-01                     Mamaearth           E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/              FinTech
# 5     2020-02-01                        Fashor  Fashion and Apparel
# ...          ...                           ...                  ...
# 3040  2015-01-29                    Printvenue                  NaN
# 3041  2015-01-29                      Graphene                  NaN
# 3042  2015-01-30                Mad Street Den                  NaN
# 3043  2015-01-30                     Simplotel                  NaN
# 3044  2015-01-31              couponmachine.in                  NaN
#
#                                  SubVertical       City  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
##Usd to cr
def inr(dollar):
    inr = dollar * 82.5
    return inr/10000000

# %%
df['Amount in USD'] = df['Amount in USD'].apply(inr)
# Out:
# C:\Users\Deep Kothari\AppData\Local\Temp\ipykernel_16860\1457518200.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Amount in USD'] = df['Amount in USD'].apply(inr)

# %%
df
# Out:
#             Date                       Startup    Industry Vertical  \
# Sr No
# 1     2020-09-01                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-09-01                     Mamaearth           E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/              FinTech
# 5     2020-02-01                        Fashor  Fashion and Apparel
# ...          ...                           ...                  ...
# 3040  2015-01-29                    Printvenue                  NaN
# 3041  2015-01-29                      Graphene                  NaN
# 3042  2015-01-30                Mad Street Den                  NaN
# 3043  2015-01-30                     Simplotel                  NaN
# 3044  2015-01-31              couponmachine.in                  NaN
#
#                                  SubVertical       City  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               3026 non-null   datetime64[ns]
#  1   Startup            3029 non-null   object
#  2   Industry Vertical  2858 non-null   object
#  3   SubVertical        2104 non-null   object
#  4   City               2849 non-null   object
#  5   Investors Name     3029 non-null   object
#  6   InvestmentnType    3027 non-null   object
#  7   Amount in USD      3029 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 213.0+ KB

# %%
len(df['Investors Name'].str.split(",").sum())
# Out:
# 5790

# %%
sorted(set(df['Investors Name'].str.split(",").sum()))
# Out:
# ['',
#  ' & Others',
#  ' 100 Co-founders Lab and others.',
#  ' 122 West Ventures',
#  ' 1Crowd',
#  ' 3ONE4 Capital Advisors',
#  ' 3one4 Capital',
#  ' 3one4 Capital Advisors LLP',
#  ' 500 Start-Ups',
#  ' 500 Startups',
#  ' 500 Startups & Other HNIs',
#  ' 50K Ventures & others',
#  ' 91SpringBoard',
#  ' 91springboard',
#  ' ABB Technology Ventures',
#  ' ABCOM Investments',
#  ' AECAL',
#  ' AET Fund',
#  ' AL Nour International Holdings and Mark V Investments',
#  ' ASP Consulting',
#  ' AVN Business Solutions',
#  ' Aarin Capital',
#  ' Aarin Capital & Others',
#  ' Aaruha Technology Fund',
#  ' Abaran Deep',
#  ' Abhai S. Rao',
#  ' Abhay Singhal',
#  ' Abhijit Bhandari',
#  ' Abhinav Patodia',
#  ' Abhinav Sinha',
#  ' Abhishek Acharya',
#  ' Abhishek Goyal',
#  ' Abhishek Gupta',
#  ' Abhishek Jain',
#  ' Abhishekh Goyal',
#  ' Abstract Ventures',
#  ' Abu Farhan Azmi',
#  ' Accel',
#  ' Accel India',
#  ' Accel Partner',
#  ' Accel Partners',
# ...

# %%
df['Investors Name']
# Out:
# Sr No
# 1                 Tiger Global Management
# 2               Susquehanna Growth Equity
# 3                   Sequoia Capital India
# 4                          Vinod Khatumal
# 5                 Sprout Venture Partners
#                       ...
# 3040          Asia Pacific Internet Group
# 3041                       KARSEMVEN Fund
# 3042       Exfinity Fund, GrowX Ventures.
# 3043                           MakeMyTrip
# 3044    UK based Group of Angel Investors
# Name: Investors Name, Length: 3029, dtype: object

# %%
df['Investors Name'] = df['Investors Name'].str.lower()
# Out:
# C:\Users\Deep Kothari\AppData\Local\Temp\ipykernel_16860\3913309182.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Investors Name'] = df['Investors Name'].str.lower()

# %%
df.rename({'Amount in USD' : "CR"}, axis=1 , inplace=True)
# Out:
# C:\Users\Deep Kothari\AppData\Local\Temp\ipykernel_16860\2697726263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename({'Amount in USD' : "CR"}, axis=1 , inplace=True)

# %%
df
# Out:
#             Date                       Startup    Industry Vertical  \
# Sr No
# 1     2020-09-01                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-09-01                     Mamaearth           E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/              FinTech
# 5     2020-02-01                        Fashor  Fashion and Apparel
# ...          ...                           ...                  ...
# 3040  2015-01-29                    Printvenue                  NaN
# 3041  2015-01-29                      Graphene                  NaN
# 3042  2015-01-30                Mad Street Den                  NaN
# 3043  2015-01-30                     Simplotel                  NaN
# 3044  2015-01-31              couponmachine.in                  NaN
#
#                                  SubVertical       City  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
df[df['Investors Name'] == 'idg ventures'][['Date' ,'Startup','Industry Vertical', 'City','InvestmentnType','CR']]
# Out:
#             Date         Startup                      Industry Vertical  \
# Sr No
# 439   2017-07-12         eShakti                              Ecommerce
# 660   2017-08-21        Uniphore                             Technology
# 2199  2015-02-11         CityFlo  Bus Aggregation and rental mobile app
# 2521  2015-08-13        Agrostar            Mobile Commerce for Farmers
# 2953  2015-09-02  MyNoticePeriod                                    NaN
#
#           City InvestmentnType       CR
# Sr No
# 439    Chennai    Debt Funding  18.9750
# 660    Chennai  Private Equity  56.1000
# 2199    Mumbai    Seed Funding   6.1875
# 2521      Pune  Private Equity  33.0000
# 2953       NaN  Private Equity  24.7500

# %%
df[df['Investors Name'].str.contains('idg ventures')].head(5)
# Out:
#             Date   Startup  Industry Vertical  \
# Sr No
# 102   2019-04-13   Tripoto       Social Media
# 223   2018-07-30  Cure Fit  Consumer Internet
# 259   2018-02-05   Bizongo  Consumer Internet
# 310   2018-04-26     POPxo         Technology
# 439   2017-07-12   eShakti          Ecommerce
#
#                                         SubVertical       City  \
# Sr No
# 102                                          Travel  New Delhi
# 223                     Health and fitness Platform  Bengaluru
# 259               Aggregator For Packaging Material     Mumbai
# 310           Women Focussed Digital Media Platform      Delhi
# 439    "Women\\'s Fashion Clothing Online Platform"    Chennai
#
#                                           Investors Name InvestmentnType  \
# Sr No
# 102    orchid india, hornbill orchid india fund, chir...        Series B
# 223    idg ventures, accel partners, kalaari capital ...  Private Equity
# ...

# %%
## Bigest Investment
df[df['Investors Name'].str.contains('idg ventures')].groupby(['Startup'])['CR'].max().sort_values(ascending=False)
# Out:
# Startup
# Cure Fit                 990.000000
# Lenskart                 495.000000
# CureFit                  206.250000
# Bizongo                  181.500000
# Vserv                    123.750000
# Curefit                  123.750000
# Fintellix                123.750000
# Xpressbees               103.125000
# FirstCry.com              82.500000
# Uniphore                  56.100000
# xc2xa0CloudCherry         49.500000
# HealthifyMe               49.500000
# Sigtuple                  47.850000
# POPxo                     45.375000
# Flyrobe                   43.725000
# RentMojo                  41.250000
# Aasaanjobs                41.250000
# Vayana                    33.000000
# Agrostar                  33.000000
# PlaySimple                33.000000
# Blowhorn                  30.112500
# Tripoto                   29.628844
# Active.ai                 24.750000
# MyNoticePeriod            24.750000
# Heckyl                    22.275000
# CreditMantri              20.625000
# ...

# %%
##Pie chart pf different sectors
sector = df[df['Investors Name'].str.contains('idg ventures')].groupby(df['Industry Vertical'])['CR'].sum().sort_values(ascending=False).head(5)
sector
# Out:
# Industry Vertical
# Consumer Internet             1719.7125
# eCommerce                      645.9750
# Technology                     350.6250
# Banking Analytics Platform     123.7500
# ECommerce                      103.1250
# Name: CR, dtype: float64

# %%
import matplotlib.pyplot as plt # type: ignore
plt.pie(sector , autopct='%1.2f%%' )
plt.show()

# %%
stages = df[df['Investors Name'].str.contains('idg ventures')].groupby(df['InvestmentnType'])['CR'].sum().sort_values(ascending=False)
stages
# Out:
# InvestmentnType
# Private Equity    3223.275000
# Seed Funding        51.562500
# Series B            29.628844
# Debt Funding        18.975000
# Seed\\nFunding       9.900000
# Name: CR, dtype: float64

# %%
import matplotlib.pyplot as plt # type: ignore
plt.pie(stages , autopct='%1.2f%%' , labels=stages.index) # type: ignore
plt.show()

# %%
df['Year'] = df['Date'].dt.year
# Out:
# C:\Users\Deep Kothari\AppData\Local\Temp\ipykernel_16860\67054256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Date'].dt.year

# %%
##year by year investment
yey = df[df['Investors Name'].str.contains('idg ventures')].groupby(['Year'])['CR'].sum()
yey
# Out:
# Year
# 2015.0     547.800000
# 2016.0    1051.050000
# 2017.0     487.987500
# 2018.0    1216.875000
# 2019.0      29.628844
# Name: CR, dtype: float64

# %%
plt.title(f"Year By Year Investment Of ")
plt.plot(yey , marker = "*")
plt.xlabel("Years")
plt.ylabel("CR")
# Out:
# Text(0, 0.5, 'CR')

# %%
df.groupby(['Investors Name'])['CR'].max()
# Out:
# Investors Name
# "kedaraa capital, ontario teachers\\'"                   160.87500
# 021 capita, binny bansal                                  24.75000
# 1crowd                                                     4.95000
# 1crowd (through crowd funding)                             1.65000
# 1crowd (through crowdfunding)                              1.72425
#                                                            ...
# zodius technology fund                                   165.00000
# zodius technology fund, khazanah nasional berhad         330.00000
# zodius technology fund, lightspeed venture partners      140.25000
# zodius technology opportunities fund, matrix partners     91.57500
# zomato media pvt. ltd                                      0.00000
# Name: CR, Length: 2371, dtype: float64

# %%
##similar investoe
df
# Out:
#             Date                       Startup    Industry Vertical  \
# Sr No
# 1     2020-09-01                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-09-01                     Mamaearth           E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/              FinTech
# 5     2020-02-01                        Fashor  Fashion and Apparel
# ...          ...                           ...                  ...
# 3040  2015-01-29                    Printvenue                  NaN
# 3041  2015-01-29                      Graphene                  NaN
# 3042  2015-01-30                Mad Street Den                  NaN
# 3043  2015-01-30                     Simplotel                  NaN
# 3044  2015-01-31              couponmachine.in                  NaN
#
#                                  SubVertical       City  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
## TAgsss

# %% [markdown]
# ## Genral Analysis

# %%
#month of month char
df['Month'] = df['Date'].dt.month_name()
# Out:
# C:\Users\Deep Kothari\AppData\Local\Temp\ipykernel_16860\1790750628.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month'] = df['Date'].dt.month_name()

# %%
df
# Out:
#             Date                       Startup    Industry Vertical  \
# Sr No
# 1     2020-09-01                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-09-01                     Mamaearth           E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/              FinTech
# 5     2020-02-01                        Fashor  Fashion and Apparel
# ...          ...                           ...                  ...
# 3040  2015-01-29                    Printvenue                  NaN
# 3041  2015-01-29                      Graphene                  NaN
# 3042  2015-01-30                Mad Street Den                  NaN
# 3043  2015-01-30                     Simplotel                  NaN
# 3044  2015-01-31              couponmachine.in                  NaN
#
#                                  SubVertical       City  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
temp_df = df.groupby(['Year' , 'Month'])['CR'].sum().reset_index()
temp_df
# Out:
#       Year      Month           CR
# 0   2015.0      April  4519.308750
# 1   2015.0     August  6378.495750
# 2   2015.0   December  2145.849750
# 3   2015.0   February  2513.697450
# 4   2015.0    January  7969.590750
# ..     ...        ...          ...
# 58  2019.0  September     8.250000
# 59  2020.0   February    39.600000
# 60  2020.0    January   140.649250
# 61  2020.0    October  1237.500000
# 62  2020.0  September  1801.460595
#
# [63 rows x 3 columns]

# %%
temp_df['x-axis'] = temp_df['Month'].astype('str') + '-' + temp_df['Year'].astype('str')

# %%
temp_df
# Out:
#       Year      Month           CR            x-axis
# 0   2015.0      April  4519.308750      April-2015.0
# 1   2015.0     August  6378.495750     August-2015.0
# 2   2015.0   December  2145.849750   December-2015.0
# 3   2015.0   February  2513.697450   February-2015.0
# 4   2015.0    January  7969.590750    January-2015.0
# ..     ...        ...          ...               ...
# 58  2019.0  September     8.250000  September-2019.0
# 59  2020.0   February    39.600000   February-2020.0
# 60  2020.0    January   140.649250    January-2020.0
# 61  2020.0    October  1237.500000    October-2020.0
# 62  2020.0  September  1801.460595  September-2020.0
#
# [63 rows x 4 columns]

# %%
temp_df[['x-axis' , 'CR']]
# Out:
#               x-axis           CR
# 0       April-2015.0  4519.308750
# 1      August-2015.0  6378.495750
# 2    December-2015.0  2145.849750
# 3    February-2015.0  2513.697450
# 4     January-2015.0  7969.590750
# ..               ...          ...
# 58  September-2019.0     8.250000
# 59   February-2020.0    39.600000
# 60    January-2020.0   140.649250
# 61    October-2020.0  1237.500000
# 62  September-2020.0  1801.460595
#
# [63 rows x 2 columns]

# %%
round(df.groupby(df['Industry Vertical'])['CR'].sum().sort_values(ascending=False).head(5))
# Out:
# Industry Vertical
# Consumer Internet    51588.0
# eCommerce            41271.0
# Transportation       32312.0
# Technology           18395.0
# Finance              16264.0
# Name: CR, dtype: float64

# %%
round(df.groupby(df['Industry Vertical'])['City'].count().sort_values(ascending=False).head(5))
# Out:
# Industry Vertical
# Consumer Internet    935
# Technology           478
# eCommerce            186
# Healthcare            70
# Finance               62
# Name: City, dtype: int64

# %%
## types of funcding and which is mpst
df['InvestmentnType'].value_counts()
# Out:
# InvestmentnType
# Private Equity                 1351
# Seed Funding                   1349
# Seed/ Angel Funding              60
# Seed / Angel Funding             47
# Seed\\nFunding                   30
# Debt Funding                     25
# Series A                         24
# Seed/Angel Funding               23
# Series B                         19
# Series C                         14
# Series D                         12
# Angel / Seed Funding              8
# Seed Round                        7
# Pre-Series A                      4
# Private Equity Round              4
# Seed                              4
# Seed / Angle Funding              3
# pre-Series A                      2
# Venture Round                     2
# Equity                            2
# Corporate Round                   2
# Series E                          2
# Series F                          2
# Private                           1
# Structured Debt                   1
# ...

# %%
## City wise funding
h = round(df.groupby(df['City'])['CR'].sum().sort_values(ascending=False).head(5))
plt.bar(x = h.index , height=h.values)
# Out:
# <BarContainer object of 5 artists>

# %%
## top investor
df.groupby(df['Investors Name'])['CR'].sum().sort_values(ascending=False).head(5)
# Out:
# Investors Name
# westbridge capital                   32604.0000
# softbank                             20625.0000
# softbank group                       12102.7500
# microsoft, ebay, tencent holdings    11550.0000
# vijay shekhar sharma                  8251.2375
# Name: CR, dtype: float64

# %%
df
# Out:
#             Date                       Startup    Industry Vertical  \
# Sr No
# 1     2020-09-01                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-09-01                     Mamaearth           E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/              FinTech
# 5     2020-02-01                        Fashor  Fashion and Apparel
# ...          ...                           ...                  ...
# 3040  2015-01-29                    Printvenue                  NaN
# 3041  2015-01-29                      Graphene                  NaN
# 3042  2015-01-30                Mad Street Den                  NaN
# 3043  2015-01-30                     Simplotel                  NaN
# 3044  2015-01-31              couponmachine.in                  NaN
#
#                                  SubVertical       City  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
## Similarcompant
ver = str(df[df['Startup'] == 'BYJU’S']['SubVertical'].values[0])

# %%
li = df[df['SubVertical'].isin([ver])]['Startup'].values[[0,1,2]]
li
# Out:
# array(['BYJU’S', 'Toppr', 'Unacademy'], dtype=object)

# %%
for i in li:
    print(i)
# Out:
# BYJU’S
# Toppr
# Unacademy

# %%
df
# Out:
#             Date                       Startup    Industry Vertical  \
# Sr No
# 1     2020-09-01                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-09-01                     Mamaearth           E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/              FinTech
# 5     2020-02-01                        Fashor  Fashion and Apparel
# ...          ...                           ...                  ...
# 3040  2015-01-29                    Printvenue                  NaN
# 3041  2015-01-29                      Graphene                  NaN
# 3042  2015-01-30                Mad Street Den                  NaN
# 3043  2015-01-30                     Simplotel                  NaN
# 3044  2015-01-31              couponmachine.in                  NaN
#
#                                  SubVertical       City  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
df[df['Startup'].str.contains("Mamaearth")]
# Out:
#             Date    Startup Industry Vertical  \
# Sr No
# 3     2020-09-01  Mamaearth        E-commerce
#
#                                  SubVertical       City  \
# Sr No
# 3      Retailer of baby and toddler products  Bengaluru
#
#               Investors Name InvestmentnType          CR    Year      Month
# Sr No
# 3      sequoia capital india        Series B  151.460595  2020.0  September

# %%
str(df[df['Startup'] == 'couponmachine.in']["InvestmentnType"])
# Out:
# 'Sr No\n3044    Seed Funding\nName: InvestmentnType, dtype: object'

# %%
df[(df['Year'] == 2019) & ( df['SubVertical'] == 'Education')].index
# Out:
# Index([68], dtype='int64', name='Sr No')

# %%
df.drop(index = 68 , inplace = True)
# Out:
# C:\Users\Deep Kothari\AppData\Local\Temp\ipykernel_16860\1046278997.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(index = 68 , inplace = True)

# %%
df.iloc[67]
# Out:
# Date                                               2019-11-07 00:00:00
# Startup                                                         Moglix
# Industry Vertical                                           E-Commerce
# SubVertical                            Industrial Tools and Equipments
# City                                                         Singapore
# Investors Name       composite capital management, sequoia capital ...
# InvestmentnType                                               Series D
# CR                                                               495.0
# Year                                                            2019.0
# Month                                                         November
# Name: 69, dtype: object

# %%
df[(df['Year'] == 2019) & ( df['SubVertical'] == 'Education')]
# Out:
# Empty DataFrame
# Columns: [Date, Startup, Industry Vertical, SubVertical, City, Investors Name, InvestmentnType, CR, Year, Month]
# Index: []

# %%
df.groupby(df['Startup'])['CR']

# %%
##toal paisaa
print(f"Total Paisaa In Indian startup {round(df['CR'].sum())}")
# Out:
# Total Paisaa In Indian startup 313789

# %%
#max
df[df['CR'] == df['CR'].max()]['Startup'].values[0]
# Out:
# 32175.0
# 'Rapido Bike Taxi'

# %%
df.groupby(['Startup'])['CR'].max().sort_values(ascending=False).index[0]
# Out:
# 'Rapido Bike Taxi'

# %%
df.groupby(['Startup'])['CR'].sum().mean()
# Out:
# 128.18167674448532

# %% [markdown]
# ## Remove duplicate name

# %%
df.to_csv("clean_startup.csv" , index=False)
